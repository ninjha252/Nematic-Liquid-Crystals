# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 100
from scipy import stats

# %%
def intersection(arr1, arr2, volt):
    for i in range(len(arr1)):
        a = (arr1[i]-arr2[i])
        if abs(np.round(a,5))<50:
            return volt[i]

# %%
data1 = pd.read_csv('34.csv')
data2 = pd.read_csv('35.csv')
data3 = pd.read_csv('36.csv')
data4 = pd.read_csv('37.csv')
data5 = pd.read_csv('38.csv')
data6 = pd.read_csv('39.csv')
data7 = pd.read_csv('40.csv')

# %%
volt1 = np.array(data1.volt)
photo1 = np.array(data1.photo)
cap1 = np.array(data1.cap)


volt2 = np.array(data2.volt)
photo2 = np.array(data2.photo)
cap2 = np.array(data2.cap)

volt2 = np.array(data2.volt)
photo2 = np.array(data2.photo)
cap2 = np.array(data2.cap)

volt3 = np.array(data3.volt)
photo3 = np.array(data3.photo)
cap3 = np.array(data3.cap)

volt4 = np.array(data4.volt)
photo4 = np.array(data4.photo)
cap4 = np.array(data4.cap)

volt5 = np.array(data5.volt)
photo5 = np.array(data5.photo)
cap5 = np.array(data5.cap)

volt6 = np.array(data6.volt)
photo6 = np.array(data6.photo)
cap6 = np.array(data6.cap)


volt7 = np.array(data7.volt)
photo7 = np.array(data7.photo)
cap7 = np.array(data7.cap)

# %%
plt.scatter(volt1, cap1, s=3, c='r', label='34C')
plt.legend()
plt.ylabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')

plt.show()
plt.scatter(volt2, cap2, s=3, c='b', label='35C')
plt.legend()
plt.ylabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')
plt.show()
plt.scatter(volt3, cap3, s=3, c='g', label='36C')
plt.legend()
plt.ylabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')
plt.show()
plt.scatter(volt4, cap4, s=3, c='crimson', label='37C')
plt.legend()
plt.ylabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')
plt.show()
plt.scatter(volt5, cap5, s=3,c='r' , label='38C')
plt.legend()
plt.ylabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')
plt.show()
plt.scatter(volt6, cap6, s=3, c='goldenrod', label='39C')
plt.legend()
plt.ylabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')
plt.show()
plt.scatter(volt7, cap7, s=3,c='forestgreen' , label='40C')
plt.legend()
plt.ylabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')
plt.show()

# %%
plt.scatter(volt1, cap1, s=3, c='r', label='34C')
plt.plot(volt1, cap1, c='k', label='34C')
plt.errorbar(volt1, cap1, xerr=0.01, yerr=0.01, c='r', ls='', capsize=2)
plt.legend()
plt.xlabel('Capacitance (nF)')
plt.xlabel('Input Voltage (V)')
plt.show()

# %%
c0=[]
v_c=[]
error_c0=[]


xquad= volt1[10:20]
yquad= cap1[10:20]
xlin= volt1[0:5]
ylin= cap1[0:5]
a,b,c= np.polyfit(xquad,yquad,2)
d,e= np.polyfit(xlin, ylin, 1)
c0.append(e)

xvals1=np.linspace(0,0.5,100)
xvals2 = np.linspace(0,1,100)
quad = np.array(a*xvals2**2+b*xvals2+c)
lin=np.array(d*xvals1+e)

arr=intersection(quad,lin,xvals2)
slope, intercept, r, p, se = stats.linregress(xlin, ylin)
error_c0.append(se)
v_c.append(arr)

xquad= volt2[10:20]
yquad= cap2[10:20]
xlin= volt2[0:5]
ylin= cap2[0:5]

a,b,c= np.polyfit(xquad,yquad,2)
d,e= np.polyfit(xlin, ylin, 1)
c0.append(e)

xvals1=np.linspace(0,0.5,100)
xvals2 = np.linspace(0,1,100)
quad = np.array(a*xvals2**2+b*xvals2+c)
lin=np.array(d*xvals1+e)

arr=intersection(quad,lin,xvals2)
slope, intercept, r, p, se = stats.linregress(xlin, ylin)
error_c0.append(se)
v_c.append(arr)


xquad= volt3[10:20]
yquad= cap3[10:20]
xlin= volt3[0:5]
ylin= cap3[0:5]

a,b,c= np.polyfit(xquad,yquad,2)
d,e= np.polyfit(xlin, ylin, 1)
c0.append(e)

xvals1=np.linspace(0,0.5,100)
xvals2 = np.linspace(0,1,100)
quad = np.array(a*xvals2**2+b*xvals2+c)
lin=np.array(d*xvals1+e)

arr=intersection(quad,lin,xvals2)
slope, intercept, r, p, se = stats.linregress(xlin, ylin)
error_c0.append(se)
v_c.append(arr)


xquad= volt4[10:20]
yquad= cap4[10:20]
xlin= volt4[0:5]
ylin= cap4[0:5]

a,b,c= np.polyfit(xquad,yquad,2)
d,e= np.polyfit(xlin, ylin, 1)
c0.append(e)

xvals1=np.linspace(0,0.5,100)
xvals2 = np.linspace(0,1,100)
quad = np.array(a*xvals2**2+b*xvals2+c)
lin=np.array(d*xvals1+e)

arr=intersection(quad,lin,xvals2)
slope, intercept, r, p, se = stats.linregress(xlin, ylin)
error_c0.append(se)
v_c.append(arr)


xquad= volt5[10:20]
yquad= cap5[10:20]
xlin= volt5[0:5]
ylin= cap5[0:5]

a,b,c= np.polyfit(xquad,yquad,2)
d,e= np.polyfit(xlin, ylin, 1)
c0.append(e)

xvals1=np.linspace(0,0.5,100)
xvals2 = np.linspace(0,1,100)
quad = np.array(a*xvals2**2+b*xvals2+c)
lin=np.array(d*xvals1+e)

arr=intersection(quad,lin,xvals2)
slope, intercept, r, p, se = stats.linregress(xlin, ylin)
error_c0.append(se)
v_c.append(arr)


xquad= volt6[10:20]
yquad= cap6[10:20]
xlin= volt6[0:5]
ylin= cap6[0:5]

a,b,c= np.polyfit(xquad,yquad,2)
d,e= np.polyfit(xlin, ylin, 1)
c0.append(e)

xvals1=np.linspace(0,0.5,100)
xvals2 = np.linspace(0,1,100)
quad = np.array(a*xvals2**2+b*xvals2+c)
lin=np.array(d*xvals1+e)

arr=intersection(quad,lin,xvals2)
slope, intercept, r, p, se = stats.linregress(xlin, ylin)
error_c0.append(se)
v_c.append(arr)

xquad= volt7[10:20]
yquad= cap7[10:20]
xlin= volt7[0:5]
ylin= cap7[0:5]

a,b,c= np.polyfit(xquad,yquad,2)
d,e= np.polyfit(xlin, ylin, 1)
c0.append(e)

xvals1=np.linspace(0,1,100)
xvals2 = np.linspace(0,1,100)
quad = np.array(a*xvals2**2+b*xvals2+c)
lin=np.array(d*xvals1+e)

plt.plot(xvals2[:60], lin[:60], c='k', ls='--')
plt.scatter(xlin, ylin, c='r')
plt.xlabel('Linear Voltage')
plt.ylabel('Linear Capacitance (Low)')



arr=intersection(quad,lin,xvals2)
slope, intercept, r, p, se = stats.linregress(xlin, ylin)
error_c0.append(se)
v_c.append(arr)

# %%
cinf=[]
error_cinf=[]

inv1 = 1/volt1[27:35]
capinv1 = cap1[27:35]
a,b = np.polyfit(inv1, capinv1, 1)
slope, intercept, r, p, se = stats.linregress(inv1, capinv1)
error_cinf.append(se)
plt.plot(inv1, a*inv1+b, c='k', ls='--')
plt.scatter(inv1, capinv1, c='r')
plt.xlabel('Inverse Voltage (1/V)')
plt.ylabel('Capacitance (High)')
plt.show()
cinf.append(b)

inv2 = 1/volt2[27:35]
capinv2 = cap2[27:35]
a,b = np.polyfit(inv2, capinv2, 1)
slope, intercept, r, p, se = stats.linregress(inv2, capinv2)
error_cinf.append(se)
cinf.append(b)


inv3 = 1/volt3[27:35]
capinv3 = cap3[27:35]
a,b = np.polyfit(inv3, capinv3, 1)
slope, intercept, r, p, se = stats.linregress(inv3, capinv3)
error_cinf.append(se)
cinf.append(b)


inv4 = 1/volt4[27:35]
capinv4 = cap4[27:35]
a,b = np.polyfit(inv4, capinv4, 1)
slope, intercept, r, p, se = stats.linregress(inv4, capinv4)
error_cinf.append(se)
cinf.append(b)


inv5 = 1/volt5[27:35]
capinv5 = cap5[27:35]
a,b = np.polyfit(inv5, capinv5, 1)
slope, intercept, r, p, se = stats.linregress(inv5, capinv5)
error_cinf.append(se)
cinf.append(b)

inv6 = 1/volt6[27:35]
capinv6 = cap6[27:35]
a,b = np.polyfit(inv6, capinv6, 1)
slope, intercept, r, p, se = stats.linregress(inv6, capinv6)
error_cinf.append(se)
cinf.append(b)

inv7 = 1/volt7[27:35]
capinv7 = cap7[27:35]
a,b = np.polyfit(inv7, capinv7, 1)
slope, intercept, r, p, se = stats.linregress(inv7, capinv7)
error_cinf.append(se)
cinf.append(b)

# %%
temp=np.array([34,35,36,37,38,39,40])
a,b,c,d=np.polyfit(temp, c0,3)
print(a,b,c,d)
fit=np.array([temp**3*a+temp**2*b + temp*c+d for temp in temp])

for i in range(len(temp)):
    
    plt.errorbar(temp[i], c0[i], yerr=error_c0[i], xerr=0,linestyle='',ecolor=None, elinewidth=None, c='r', capsize=1, markersize=error_c0[i], barsabove=True)
    plt.xlabel(r'Temperature ($^\circ$C)')
    plt.ylabel(r'Zero Voltage Capacitance. ($C_0$)')
plt.errorbar(temp, c0, yerr=error_c0[0], xerr=0,linestyle='',ecolor=None, elinewidth=None, c='r', capsize=1, markersize=error_c0[i], barsabove=True, label=r'$\Delta C_0$')
plt.scatter(temp, c0, c='k', label=r'$C_0$')
plt.plot(temp, fit, c='k', ls='--', label='3rd Order Fit')
plt.legend()
plt.show()
# Out:
# 1.298696666662642 -140.0961085709709 5053.106063316009 -60157.58357692451

# %%
a,b,c,d = np.polyfit(temp, cinf,3)
fit_inf=np.array([a*temp**3+b*temp**2+c*temp+d for temp in temp])
plt.plot(temp, fit_inf, c='k', ls='--',label='3rd Order Fit')
plt.scatter(temp, cinf, c='k', label=r'$C_{\infty}$')
plt.errorbar(temp, cinf,  yerr=error_cinf[0],xerr=0.1,linestyle='', c='r', capsize=0.1, barsabove=True, label=r'$\Delta C_{\infty}$')
print(a,b,c,d)
for i in range(len(temp)):
    val = error_cinf[i]
    plt.errorbar(temp[i], cinf[i],  yerr=val,xerr=0.1,linestyle='', c='r', capsize=2, barsabove=True)
    plt.xlabel(r'Temperature ($^\circ$C)')
    plt.ylabel(r'High Voltage Capacitance. ($C_{\infty}$)')
plt.legend()
plt.show()
# Out:
# -1.953344810049655 210.43002469822224 -7562.007558905215 92474.11088853476

# %%
p,q,r,s=np.polyfit(temp, v_c,3)
len(v_c)
fit_vc=np.array([p*temp**3+q*temp**2+r*temp+s for temp in temp])

# %%
plt.scatter(temp, v_c, c='r', s=4,label=r'$V_c$')
plt.errorbar(temp, v_c, xerr=0, yerr=0.01, ls='', c='r', capsize=2, label=r'$\Delta V_c$')
plt.plot(temp, fit_vc, c='k', ls='--', label='3rd order Fit')
plt.xlabel(r'Temperature ($^\circ$C)')
plt.ylabel(r'Critical Voltage ($V_c$)')
plt.legend()
plt.show()

# %%
L0 = 5.55e-6
e0=8.85e-12
area=1.5e-4
epsilonp = []


C_0 = np.array([742.13, 762.23, 780.29, 801.53, 826.53, 858.59, 930.59])*1e-12
C_inf= np.array([1846.24, 1836.75, 1822.35, 1813.19, 1790.78, 1757.23, 1664.82])*1e-12
T = np.array([34, 35, 36, 37, 38, 39, 40])
gamma = (C_inf/C_0)-1


for i in range(len(c0)):
    ep=L0*C_0[i]/(area*e0)
    epsilonp.append(ep)
    
epsilon_parallel= (gamma+1)*epsilonp

# %%
#gamma
error_gamma=[]
for i in range(len(gamma)):
    dg = np.sqrt(error_cinf[i]/cinf[i] + error_c0[i]/c0[i])
    error_gamma.append(dg)

print(gamma)
print(error_gamma)
# Out:
# [1.48775821 1.40970573 1.33547784 1.26216112 1.16662432 1.04664625
#  0.78899408]
# [0.03565360230984104, 0.030101362136886488, 0.14626332419813728, 0.05154152527230675, 0.04123857755977146, 0.05485133781161592, 0.05542697575305702]

# %%
print(C_inf)
# Out:
# [1.84624e-09 1.83675e-09 1.82235e-09 1.81319e-09 1.79078e-09 1.75723e-09
#  1.66482e-09]

# %%
a,b,c,d=np.polyfit(temp, gamma, 3)
fit_gamma=np.array([a*temp**3+b*temp**2+c*temp+d for temp in temp])
print(a,b,c,d)
plt.plot(temp, fit_gamma, c='k', ls='--', label='3rd Order Fit')
plt.scatter(temp, gamma, c='k', label=r'$\gamma$')
for i in range(len(gamma)):
    plt.errorbar(temp[i], gamma[i], yerr=error_gamma[i], xerr=0.1, ls='', c='r', capsize=3)
plt.errorbar(temp, gamma, yerr=error_gamma[0], xerr=0.1, ls='', c='r', capsize=1, label=r'$\Delta \gamma$')
plt.xlabel(r'Temperature ($^\circ$C)')
plt.ylabel(r'$\gamma$')
plt.legend()
plt.show()
# Out:
# -0.004634753610219749 0.5005149186712564 -18.077558517733188 219.69859669031132

# %%
error_eperp=[]
for i in range(len(c0)):
    e = error_c0[i]*epsilonp[i]/c0[i]
    error_eperp.append(e)
    
    
    

error_eparal=[]
for i in range(len(gamma)):
    e=np.sqrt((error_gamma[i]/gamma[i])**2+(error_eperp[i]/epsilonp[i])**2)*epsilon_parallel[i]
    error_eparal.append(e)
   
print(epsilon_parallel)
print(error_eparal)
# Out:
# [7.7187435  7.6790678  7.61886441 7.58056836 7.48687684 7.3466113
#  6.96026441]
# [0.18498080968804032, 0.16399125661232689, 0.8345757586353398, 0.3098692844622144, 0.26480578665605947, 0.3855186122736019, 0.48901688974860397]

# %%
a,b,c,d=np.polyfit(temp, epsilonp,3)
ep_fit=np.array([a*i**3+b*i**2+c*i+d for  i in temp])
p,q,r,s = np.polyfit(temp, epsilon_parallel,3)
epar_fit=np.array([p*i**3+q*i**2+r*i+s for  i in temp])



plt.scatter(temp, epsilonp, c='r', label=r'$\epsilon_\perp$')
plt.plot(temp, ep_fit, c='k', ls='--', label='3rd Order Fit')
plt.plot(temp, epar_fit, c='r', ls='--', label='3rd Order Fit')
plt.scatter(temp, epsilon_parallel, c='b', label=r'$\epsilon_{||}$')
plt.errorbar(temp,epsilonp, yerr=error_eperp[0], xerr=0.1, ls='', c='b', label=r'$\Delta \epsilon_\perp$')
plt.errorbar(temp,epsilon_parallel, yerr=error_eparal[0], xerr=0.1, ls='', c='g', label=r'$\Delta \epsilon_{||}$')

for i in range(len(epsilonp)):
    plt.errorbar(temp[i],epsilonp[i], yerr=error_eperp[i], xerr=0.1, ls='', c='b',capsize=3)
    plt.errorbar(temp[i],epsilon_parallel[i], yerr=error_eparal[i], xerr=0.1, ls='', c='g',capsize=3)

    


plt.xlabel('Temperature')
plt.ylabel(r'$\epsilon_{perp}$')
plt.legend(fontsize=7)
plt.show()

# %%
k11=[]

for i in range(len(epsilonp)):
    k = (v_c[i]/np.pi)**2*e0*epsilonp[i]*gamma[i]
    k11.append(k)

# %%
error_k11=[]
for i in range(len(k11)):
    e = np.sqrt(2*(0.1/v_c[i])**2+(error_eperp[i]/epsilonp[i])**2)*k11[i]
    error_k11.append(e)
    
print(error_k11)
# Out:
# [5.144149452153965e-13, 4.833664087784039e-13, 4.4647234337403284e-13, 4.0634828009933694e-13, 3.511460901428831e-13, 2.839536285536165e-13, 1.5728088365327875e-13]

# %%
p,q,r=np.polyfit(temp, k11, 2)
fit_k11=np.array([p*temp**2+q*temp+r for temp in temp])

for i in range(len(k11)):
    plt.errorbar(temp[i], k11[i], yerr=error_k11[i], xerr=0.1, ls='', c='r',capsize=3)
    plt.scatter(temp[i], k11[i], c='r', s=6)
plt.plot(temp, fit_k11, c='k', ls='--', label='2nd Order Fit')
plt.xlabel('Temperature')
plt.ylabel(r'Splay Constant ($K_{11}$) ')
plt.show()

# %%
small_v1 = volt1/v_c[0] - 1
small_c1 = cap1/c0[0] - 1

small_v2 = volt2/v_c[1] - 1
small_c2 = cap2/c0[1] - 1

small_v3 = volt3/v_c[2] - 1
small_c3 = cap3/c0[2] - 1

small_v4 = volt4/v_c[3] - 1
small_c4 = cap4/c0[3] - 1

small_v5 = volt5/v_c[4] - 1
small_c5 = cap5/c0[4] - 1

small_v6 = volt6/v_c[5] - 1
small_c6 = cap6/c0[5] - 1

small_v7 = volt7/v_c[6] - 1
small_c7 = cap7/c0[6] - 1

# %%
small_v7
# Out:
# array([-7.5250e-01, -5.0500e-01, -2.5750e-01, -1.0000e-02,  2.3750e-01,
#         4.8500e-01,  7.3250e-01,  9.8000e-01,  1.2275e+00,  1.4750e+00,
#         1.7225e+00,  1.9700e+00,  2.2175e+00,  2.4650e+00,  2.7125e+00,
#         2.9600e+00,  3.2075e+00,  3.4550e+00,  3.7025e+00,  3.9500e+00,
#         4.1975e+00,  4.4450e+00,  4.6925e+00,  4.9400e+00,  5.1875e+00,
#         6.4250e+00,  8.9000e+00,  1.1375e+01,  1.3850e+01,  1.6325e+01,
#         1.8800e+01,  2.1275e+01,  2.3750e+01,  2.6225e+01,  2.8700e+01,
#         3.1175e+01,  3.3650e+01,  3.6125e+01])

# %%
small_v = ([small_v1, small_v2,small_v3,small_v4,small_v5,small_v6,small_v7])
small_c = ([small_c1,small_c2,small_c3,small_c4,small_c5,small_c6,small_c7])

# %%
#low field kappa

small_clow= small_c1[:10]
small_vlow= (small_v1[:10])

a,b = np.polyfit(small_vlow, small_clow,1)
small_vlow
# Out:
# array([-0.8862069 , -0.77241379, -0.65862069, -0.54482759, -0.43103448,
#        -0.31724138, -0.20344828, -0.08965517,  0.02413793,  0.13793103])

# %%
def kappa_low(gamma, slope):
    m=slope
    g=gamma
    kappa_low = g*((2/m) - 1)-1
    
    return kappa_low

# %%
k=kappa_low(gamma[0], a)
a
# Out:
# 0.04020594111755539

# %%
small_clow= small_c2[:12]
small_vlow= small_v2[:12]

a,b = np.polyfit(small_vlow, small_clow,1)

# %%
k=kappa_low(gamma[1], a)

# %%
k33 = (k+1)*k11[0]

# %%
m=[]
error_m=[]

small_clow= small_c1[:15]
small_vlow= small_v1[:15]
a,b = np.polyfit(small_vlow, small_clow,1)
slope, intercept, r, p, se = stats.linregress(inv1, capinv1)
error_m.append(se)
m.append(a)



small_clow= small_c2[:15]
small_vlow= small_v2[:15]

a,b = np.polyfit(small_vlow, small_clow,1)
slope, intercept, r, p, se = stats.linregress(inv2, capinv2)
error_m.append(se)
m.append(a)

small_clow= small_c3[:15]
small_vlow= small_v3[:15]

a,b = np.polyfit(small_vlow, small_clow,1)
slope, intercept, r, p, se = stats.linregress(inv3, capinv3)
error_m.append(se)
m.append(a)

small_clow= small_c4[:15]
small_vlow= small_v4[:15]

a,b = np.polyfit(small_vlow, small_clow,1)
slope, intercept, r, p, se = stats.linregress(inv4, capinv4)
error_m.append(se)
m.append(a)

small_clow= small_c5[:15]
small_vlow= small_v5[:15]

a,b = np.polyfit(small_vlow, small_clow,1)
slope, intercept, r, p, se = stats.linregress(inv5, capinv5)
error_m.append(se)
m.append(a)

small_clow= small_c6[:15]
small_vlow= small_v6[:15]

a,b = np.polyfit(small_vlow, small_clow,1)
slope, intercept, r, p, se = stats.linregress(inv6, capinv6)
error_m.append(se)
m.append(a)

small_clow= small_c7[:15]
small_vlow= small_v7[:15]

a,b = np.polyfit(small_vlow, small_clow,1)
slope, intercept, r, p, se = stats.linregress(inv1, capinv1)
error_m.append(se)

m.append(a)

# %%
kappa=[]
k33=[]
for i in range(len(m)):
    k = kappa_low(gamma[i], m[i])
    kappa.append(k)
    k3 = (k+1)*k11[i]
    k33.append((k3))

# %%
error_kappa=[]
error_k33=[]
for i in range(len(gamma)):
    k = np.sqrt((error_gamma[i]/gamma[i])**2+(error_m[i]/m[i])**2)
    error_kappa.append(k)
    
    er = np.sqrt(((k/100)/kappa[i])**2+(error_k11[i]/k11[i])**2)*k33[i]
    error_k33.append(er)
print(k33)
# Out:
# [3.2716692622265306e-11, 2.0937824751767815e-11, 1.621843267316083e-11, 1.3142218510275026e-11, 1.0262874412809936e-11, 7.580218337607057e-12, 3.901426235803774e-12]

# %%
a,b,c,d = np.polyfit(temp, k33, 3)
fit_k33=np.array([a*t**3+b*t**2+c*t+d for t in temp])
print(a,b,c,d)
plt.plot(temp, fit_k33, c='k', ls='--')
plt.plot(temp,fit_k11, c='r', ls='--')
plt.scatter(temp, k33,c='r', label=r'$k_{33}$')
plt.scatter(temp, k11,c='k', label=r'$k_{11}$')

for i in range(len(kappa)):
    plt.errorbar(temp[i], k33[i], yerr=error_k33[i]/80, c='k', ls='', capsize=2)
    plt.errorbar(temp[i], k11[i], yerr=error_k11[i]/80, c='r', ls='',capsize=2)
plt.xlabel(r'Temperature ($^\circ$C)')
plt.ylabel(r'Elastic constants (${K_N}$)')
plt.legend()
plt.show()
# Out:
# -2.639472697759029e-13 2.9906215980733913e-11 -1.1314350779393872e-09 1.4303742655598052e-08

# %%
a,b,c=np.polyfit(temp, kappa, 2)
fit_kappa = [a*i**2+b*i+c for i in temp]
print(a,b,c)
plt.plot(temp, fit_kappa, c='k', ls='--')
plt.scatter(temp, (kappa), c='k', label=r'Low field $\kappa$ values')
for i in range(len(kappa)):
    plt.errorbar(temp[i], kappa[i], yerr=error_kappa[i]/150, c='r', ls='', capsize=2)
plt.xlabel(r'Temperature ($^\circ$C)')
plt.ylabel(r'Low Field Kappa ($\kappa_{LFC}$) ')
plt.legend()
plt.show()
# Out:
# 0.3965385672340198 -29.58553518104953 556.4867321288482

# %% [markdown]
# ### Birefringence

# %%
n = np.array([0.254432432, 0.251081081, 0.249963964, 0.238972973, 0.234630631, 0.230342342, 0.22609009, 0.218720721, 0.212504505, 0.199333333, 0.186585586, 0.181783784 ])
T=np.array([30, 32, 33, 34, 35, 36, 37, 38, 39, 40, 40.5, 40.6 ])

# %%
a,b,c,d=np.polyfit(T, n, 3)
fit  = np.array([a*i**3+b*i**2+c*i+d for i in T])


plt.plot(T, n, c='k', label='Birefringence', ls='dashdot')
plt.scatter(T, n, c='r', label='Birefringence', ls='dashdot')
plt.axvline(34, c='g', ls='--', label='Smectic Phase Transition')

#plt.plot(T, fit, c='k', ls='--', label='3rd Order Fit')
#plt.errorbar(T, fit, yerr=0.005, xerr=0.1, c='r', ls='', capsize=4)
plt.xlabel(r'Temperature ($^\circ$ C)')
plt.ylabel(r'$\Delta n$')
plt.legend()
plt.show()

# %%
T1 = np.array([30, 32, 34, 35, 36, 37, 38, 39, 40, 40.5, 41, 41.5, 42 ])
n1 = np.array([0.274473874,0.274473874,0.268096577,0.255467027,0.252340901,0.246213694,0.240149009,0.237085405,0.231208288,0.225331171,0.219579099,0.213827027,0.205386487])

# %%
a,b,c,d=np.polyfit(T1, n1, 3)
fit  = np.array([a*i**3+b*i**2+c*i+d for i in T1])


plt.plot(T1, n1, c='k', label='Birefringence', ls='dashdot')

plt.scatter(T1, n1, c='r', label='Birefringence')
plt.axvline(35, c='g', ls='--', label='Smectic Phase Transition')
#plt.plot(T1, fit, c='k', ls='--', label='3rd Order Fit')
plt.xlabel(r'Temperature ($^\circ$ C)')
plt.ylabel(r'$\Delta n$')
plt.legend()
plt.show()

# %% [markdown]
# ### optical transition

# %%
n1=n1[2:9]

# %%
d0 =[]
for i in range(len(n1)):
    a = 2*np.pi*(5.55e-6)*n1[i]/546e-9
    d0.append(a)

# %%
plt.scatter(temp, d0, c='k', label=r'phase-difference')
